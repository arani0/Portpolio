# %% [markdown]
# # 파이널 프로젝트 계획 보고서
#
# 이 파일은 작성 예시를 보여주는 샘플입니다.
#
# | 조 / 이름 | 4조 / 이새찬, 김영진, 전관배, 김가람 |
# | --- | --- |
# | 제출일 | 2026-09-17 |
# | 데이터셋 이름 | 데이터분석 지역화폐 행정동 소비 |
# | 데이터 URL | https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=H32V086XPDGQFXIV4FWD38131115&infSeq=1&page=1&size=10&sort=reg |
# | 데이터셋 이름 | 데이터분석 유동인구 요일별 행정동 |
# | 데이터 URL | https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=QG3PQ8O43NXGS62A95GO38124431&infSeq=1&page=1&size=10&sort=reg |
# | 데이터셋 이름 | 지역화폐 가맹점 현황 (경기도) |
# | 데이터 URL | https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=3NPA52LBMO36CQEQ1GMY28894927&infSeq=1&page=1&size=10&sort=reg |
# | 데이터셋 이름 |행정동별 생활인구  |
# | 데이터 URL | https://jumin.mois.go.kr/statMonth.do |

# %% [markdown]
# ## 1. 어떤 데이터인가
#
#
# | 항목 | 설명 |
# | --- | --- |
# | 원본 출처 | 경기데이터분석포털에서 분석을 위해 AI데이터행정과가 제공하는 자료로 경기데이터드림에서 수집 |
# | 수집 시점·기간 | 2023년 7월 ~ 2025년 6월 매출 24개월치. 기준일자 25.09.18. 2026년 9월 2일 내려받음 |
# | 데이터 크기 | 10,398행 × 4열 |
# | 파일 구성 | 2023, 2024, 2025 데이터가 따로 존재하여 2023.07 ~ 2025.06까지 합침. 업종별 매출로 나뉘어있지만 23년도부터 총매출만 존재하여 업종분류코드 열은 삭제. |
# | 한 행의 데이터 단위 | 행정동x기준년월 매출. 월별로 행정동 매출이 반복됨. |
# | 원본 출처 | 경기데이터분석포털에서 분석을 위해 AI데이터행정과가 제공하는 자료로 경기데이터드림에서 수집 |
# | 수집 시점·기간 | 2023년 7월 ~ 2025년 6월 매출 24개월치. 기준일자 25.10.13. 2026년 9월 2일 기준으로 내려받음 |
# | 데이터 크기 | 112,392행 11열 |
# | 파일 구성 | 행정동별·월별·요일별 유동인구가 하나의 파일에 통합되어 있으며, 요일코드는 MON~SUN과 TOT로 구성 |
# | 한 행의 데이터 단위 | 행정동 × 기준년월 × 요일코드별 유동인구 1건 |
# | 원본 출처 | 경기지역화폐로 부터 가맹점 자료를 제공받아 경기데이터드림에서 공개하는 원자료  |
# | 수집 시점·기간 | 2023년 12월 ~ 2025년 8월 지역화폐가맹점 약 21개월치.<p>23년: 23.12.31 기준, 24년: 24.10.17 기준, 25년: 25.08.01 기준으로 내려받음. 2026년 9월 2일 수집 |
# | 데이터 크기 | 23년: 403,472행 x 15열<p>24년: 418,749행 x 14열<p>25년: 408,991행 x 15열 |
# | 파일 구성 | 2023, 2024, 2025 데이터가 따로 존재하여 2023.12 ~ 2025.08까지 합침.<p>열 구성이 데이터기준일자 열을 제외한 모두 같아 그대로 이어 붙이면 됨. |
# | 한 행의 데이터 단위 | 가게 1건. 같은 상호명이어도 하나의 소모처로 따로 식별해야 하므로 전부 개별적인 행 |
# | 원본 출처 | 행정안전부 주민등록 인구통계 |
# | 수집 시점·기간 | 2023년 7월 ~ 2025년 6월/9월 7일 기준으로 수집|
# | 데이터 크기 | 11136행 X 4열 |
# | 파일 구성 | 2023년 7월~2025년 6월 경기도 464개 행정동의 월별 주민등록인구를 행정동코드·행정구역·기준연월·총인구수 4개 컬럼으로 정리한 데이터  |
# | 한 행의 데이터 단위 | 행정동 × 월별 1건이고, 464개 행정동 × 24개월 = 11,136행 |

# %% [markdown]
# ## 2. 데이터 선정 이유

# %% [markdown]
# ### 계기
#
# 지인에게 지역화폐로 자녀들의 학원비를 낸다는 이야기를 듣고 그렇다면 지역화폐는 소상공인, 지역상권에 도움을 주지 못하고 정기적인 소비를 대체하는것이 아닌가? 라는 의구심이 들었다. 이러한 궁금증을 바탕으로 지역화폐 제도의 실효성에 대해 비판적으로 분석해보고 실효성이 있다면 어떤 요인이 상관관계가 있는지, 없다면 정책의 개선에 도움을 줄 수 있는 인사이트를 발굴해보고자 한다.

# %% [markdown]
# ### 고른 이유
#
# 경기데이터드림에 지역화폐 소비량이 행정동 단위로 존재했다. 서울시의 경우 구단위로 소비량을 확인할 수 있어 보다 많은 행을 확보하기 위해 경기도를 공간적 범위로 설정하였고 소비량에 영향을 미치는 생활인구, 유동인구 데이터를 수집했고 특정 매장에서만 사용할 수 있다는 지역화폐의 특징을 반영하여 지역화폐 사용 가능 매장 데이터를 수집하였다.

# %% [markdown]
# ### 비교한 다른 데이터셋 후보
#
#
# #### 후보 ①
#
# | 데이터셋 이름 | 서울시 서울사랑상품권 발행, 판매, 결제 현황 |
# | --- | --- |
# | URL | https://data.seoul.go.kr/dataList/OA-22395/F/1/datasetView.do |
# | 크기 | 서울 기준 26.03까지 구별 지역화폐 소비량 |
# | 제외한 이유 | 구단위 데이터라 3년*26개구의 데이터로 데이터의 크기가 비교적 작다 |
#
#
# #### 후보 ②
#
# | 데이터셋 이름 |유동인구_행정동 단위 집계  |
# | --- | --- |
# | URL | https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=CQC4H00RD22ALSXD8J8Z34795536&infSeq=1&page=1&size=10&sort=reg |
# | 크기 | 월별 경기도 시단위 행정동 유동인구수 |
# | 제외한 이유 | 일부 시의 데이터만 존재, 행정동 단위 집계로 표기되어 있으나 행정동 단위로 집계되지 않고 시단위에서 행정동 수 기준 단순 나눈 수로 표기 |
#
#
# #### 후보 ③
#
# | 데이터셋 이름 | 경기도_카드업종중분류_지역화폐 업종구분별 매출 |
# | --- | --- |
# | URL | https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=21P6SA4OOH5AW25V3QRP38272636&infSeq=1&page=1&size=10&sort=reg |
# | 크기 | 경기도 기준 20.12부터 21.06까지 143,907행 x 12열 |
# | 제외한 이유 | 데이터의 연도가 코로나 시기인 20~21년도 이므로 특수성을 가져 최근의 지역화폐 소모량에 대한 수치를 오염시킨다. |
#
#
# #### 후보 ④
#
# | 데이터셋 이름 | 경기도_지역화폐_업종구분별_매출정보 |
# | --- | --- |
# | URL | https://data.gg.go.kr/portal/data/service/selectServicePage.do?infId=DH27RU6U6ZPGV33C533H38201362&infSeq=1&page=1&size=10&sort=reg |
# | 크기 | 143,907행 × 9열 |
# | 제외한 이유 | 데이터의 연도가 코로나 시기인 20~21년도 이므로 특수성을 가져 최근의 지역화폐 소모량에 대한 수치를 오염시킨다. |

# %% [markdown]
# ## 3. 무엇을 분석할 것인가
#
#
# - 한 문장 요약: 생활인구, 유동인구, 업종별 지역화폐 가맹점 수로 지역화폐 소비량의 상관관계에 대해 분석한다.
#
# - 핵심 질문: 지역적 특성, 가맹점 수, 업종에 따라 지역화폐의 효과가 달라지는가?
#
# - 문제 유형: ☑ 회귀 ☐ 분류 ☐ 군집 ☐ 시계열
#   - 근거: Y가 386~892,136,990원 사이의 금액이라 연속형이다. 각 요인이 매출금액에 어느 정도 관련되는지 확인하는 것이므로 회귀 문제로 판단하였다.

# %% [markdown]
# ### 목표변수 Y
#
#
# | 컬럼명 | 지역화폐 소비량 |
# | --- | --- |
# | 척도 | 연속형(비율척도), 금액단위 원 |
# | 분포 · 범주 비율 | 최소 386 / 중앙값 846,558 / 평균 18,829,867 / 최대 892,136,990. 평균이 중앙값보다 2,124.3% 크다. 일부 매우 큰 값이 평균을 끌어올림을 예상 |

# %% [markdown]
# ### 설명변수 X
#
#
# #### X ①
#
# | 컬럼명 | 행정동 코드 |
# | --- | --- |
# | 의미 · 단위 | 각 행정동을 의미하는 코드 |
# | Y와 관련 있다고 보는 이유 | 지역특징을 가지고있는 공간적 변수 |
#
#
# #### X ②
#
# | 컬럼명 | 총인구수 |
# | --- | --- |
# | 의미 · 단위 | 경기도의 행정동 중 260개 행정동의 생활인구 수 |
# | Y와 관련 있다고 보는 이유 | 인구가 많을수록 매출에 영향을 준다고 판단 |
#
#
# #### X ③
#
# | 컬럼명 | 월 유동인구수 |
# | --- | --- |
# | 의미 · 단위 | 월별x행정동별 유동인구 수 |
# | Y와 관련 있다고 보는 이유 | 유동인구가 많을수록 매출에 영향을 준다고 판단 |
#
#
# #### X ④
# | 컬럼명 | 가맹점 수(11개 컬럼 - 업종대분류10개 + 기타) |
# |---|---|
# | 의미 · 단위 | 행정동별·월별·업종별 지역화폐 가맹점 개수, 개 |
# | Y와 관련 있다고 보는 이유 | 지역화폐를 사용할 수 있는 가맹점이 많을수록 소비자가 지역화폐를 사용할 수 있는 선택지가 증가하므로 지역화폐 소비량도 증가할 것으로 예상한다. 특히 음식점·소매업 등 업종별 가맹점 구성에 따라 소비량에 차이가 있을 수 있는지 확인한다. |

# %% [markdown]
# ### 가설
#
#
# - ① 연도에 따라 지역화폐 매출액에 차이가 없다.(지역화폐의 혜택 한도가 천장역할)
#
# - ② 업종 종류를 제한했을 때 가맹점이 많을수록 지역화폐 소비량이 높을 것이다.(접근성의 영향)
#
# - ③ 업종 종류에 따라 지역화폐 매출액에 차이가 존재하는 업종이 존재할 것이다.

# %% [markdown]
# > **📝 작성방법 설명**
# >
# >
# > - 핵심 질문
# >   - 데이터로 답이 나오는 형태로 씁니다.
# >   - “어떻게 하면 집을 싸게 살까”(×) — 방법은 데이터에 없습니다.
# >   - “지은 지 오래된 아파트일수록 거래금액이 낮게 나타나는가”(○)
# >
# > - 문제 유형
# >   - 근거는 Y의 척도입니다. “분류를 하고 싶어서”(×) → “Y가 금액이라 연속형”(○)
# >   - 연속형 Y를 억지로 구간으로 잘라 분류로 바꾸면 자르는 기준을 스스로 정해야 하고 “얼마나 차이 나는가”라는 정보가
# > 버려집니다. 굳이 그렇게 한다면 이유를 적으세요.
# >
# > - 목표변수 Y
# >   - 분포는 지금 세어 둡니다. 범주가 9:1로 쏠려 있으면 전부 다수 범주로 찍기만 해도 정확도 90%가 나옵니다. 나중에 발
# > 견하면 평가 지표부터 다시 정해야 합니다.
# >   - 연속형이라면 최소·최대·중앙값·평균을 적고 평균과 중앙값이 크게 벌어지는지 확인합니다. 위 예시처럼 벌어지면
# > 그대로 회귀에 넣기 어려워 로그 변환을 검토해야 합니다.
# >
# > - 설명변수 X
# >   - 컬럼명을 그대로 옮겨 적습니다. “아파트 정보들”처럼 뭉뚱그리면 다음 주에 무엇을 쓸지 다시 정해야 합니다.
# >   - 원본 컬럼을 가공해 쓸 계획이라면 위 X ④·⑤처럼 계산식과 함께 적습니다.
# >   - Y에서 만들어진 값을 넣으면 안 됩니다. 위 예시의 ㎡당 가격이 그렇습니다. 별점으로 긍정/부정 라벨을 만들어 놓고
# > 별점을 설명변수로 넣는 것과 같은 실수이고 매년 나옵니다. 목록을 다 적은 뒤 하나씩 “이 값은 Y가 정해지기 전에 알
# > 수 있는 값인가”를 물어보세요.
# >   - X와 Y 양쪽에 영향을 주는 변수를 빠뜨리기 쉽습니다. 아이스크림 판매량과 익사 사고 수는 같이 올라가지만 둘 다 기온
# > 때문입니다. 위 예시에서는 자치구와 계약 시점이 그 자리에 있어 X ②·⑤로 넣고 이유를 밝혔습니다.
# >
# > - 가설
# >   - 방향까지 적고 틀릴 수 있는 문장으로 씁니다. “넓으면 비싸다”처럼 결과가 뻔한 문장은 확인해도 얻는 게 없습니다.
# >   - 위 가설 ②처럼 “조건을 맞춰서 비교해도 그런가”를 묻는 형태, 가설 ③처럼 “관계가 없을 것이다”라고 거는 형태가 확
# > 인할 가치가 있습니다.
# >
# > - 이 절을 다 쓴 뒤 점검
# >   - 핵심 질문 · 문제 유형 · Y 세 가지를 나란히 놓고 읽어 봅니다. 셋이 같은 것을 가리켜야 합니다.
# >   - 질문은 “어느 집단이 더 높은가”인데 Y는 연속값이고 문제 유형은 회귀로 적어 놓는 식의 어긋남이 매년 나옵니다. 이
# > 상태로 5주를 가면 마지막에 질문과 결과가 맞지 않아 결론을 못 씁니다.
# >   - 위 예시는 질문도 “얼마나 낮은가”, Y도 연속형 금액, 유형도 회귀로 맞물려 있습니다. 어긋났다면 셋 중 무엇을 고칠지
# > 지금 정하세요. 대개 질문을 다듬는 쪽이 빠릅니다.

# %% [markdown]
# ## 4. 데이터 실물 확인
#
#
# | 행 × 열 | 59,842행 × 10열 |
# | --- | --- |
# | 결측 많은 컬럼 | 해제사유발생일 57,918건(96.8%). 나머지 9개 컬럼은 결측 없음 |
# | 이상한 값 | 거래금액 최댓값 1,150,000만원(115억), 전용면적 최댓값 273.9㎡. 확인해 보니 오류가 아니라 실제 대<br>형 평형. 층 값에 -1이 312건 있는데 지하층을 뜻함 |
# | Y 분포 | 9,500~1,150,000만원, 중앙값 92,000, 평균 128,340. 평균이 중앙값보다 커서 오른쪽으로 꼬리가<br>긴 형태 |
# | 중복 행 | 0건. 다만 같은 단지·같은 날짜 거래가 여러 건 있는데 층이 달라 서로 다른 거래다 |
# | 자료형이 잘못 읽힌 컬럼 | 거래금액이 82,500처럼 콤마가 들어간 문자열이라 문자로 읽힘. 건축년도와 층도 문자열 |
# | 범주형 컬럼의 값 종류 수 | 자치구 25종 — 더미 인코딩해도 열이 24개만 늘어 부담 없음. 아파트 이름은 3,847종이라 그대로 못 씀 |

# %% [markdown]
# ### 발견한 내용
#
# 가장 먼저 걸린 건 결측이 결측이 아니었다는 점이다. 해제사유발생일이 96.8% 비어 있어서 처음에는 쓸모없는
# 컬럼으로 보고 지우려 했다. 그런데 이 값이 채워진 1,924건은 계약이 취소된 거래였다. 컬럼을 지웠으면 실제로
# 성사되지 않은 거래 1,924건이 그대로 분석에 들어갈 뻔했다. 비어 있는 쪽을 남기고 채워진 쪽을 빼는 것이 맞
# 다.
# 자치구가 가격의 대부분을 설명한다는 것도 분명해졌다. 강남구 중앙값 245,000과 노원구 51,500이 다섯 배 가
# 까이 벌어져서 자치구를 넣지 않고 모델을 돌리면 다른 변수들이 자치구를 대신 설명하는 꼴이 된다. 강남구에
# 큰 평수가 많다면 면적의 효과가 실제보다 부풀려진다. 그래서 자치구를 X에 넣고 EDA 단계에서 구별로 나눠서
# 도 확인하기로 했다.
# 거래금액이 콤마 때문에 문자로 읽히는 것도 미리 열어보지 않았으면 놓쳤을 문제다. 그대로 두면 평균조차 계산
# 되지 않는다. 층의 -1도 처음에는 오류로 봤는데 지하층을 뜻하는 값이었다. 그냥 지우면 반지하 거래 312건이
# 사라진다.
# 아파트 이름은 3,847종이다. 그대로 더미 인코딩하면 열이 3,847개로 불어나고 한 단지에 거래가 한두 건뿐인 곳
# 도 많아 학습이 되지 않는다. X에서 빼고 자치구 단위로만 보기로 했다.
# 한 가지 더, 실거래 자료에는 팔린 물건만 있다. 내놨는데 안 팔린 물건은 기록되지 않는다. 그래서 여기서 나오
# 는 결론은 “거래된 아파트의 가격을 가르는 요인”이지 “서울 아파트 전체의 가치”가 아니다. 발표 자료의 한계
# 장에 적기로 했다.
# 아직 전처리는 하지 않았다. 위 수치는 info() · describe() · value_counts() · isna().sum()으로 확인만
# 한 결과다.

# %% [markdown]
# > **📝 작성방법 설명**
# >
# >
# > - 확인 방법 (표 전체 공통)
# >   - 데이터를 직접 내려받아 head() · info() · describe() · value_counts() · isna().sum()으로 확인하고 그 결과
# > 를 옮겨 적습니다. 남의 노트북 화면을 보고 적으면 안 됩니다.
# >   - 데이터의 모습을 확인하지 않은 채 주제를 확정하면, 분석을 시작한 뒤에 데이터 상태 때문에 주제를 바꾸거나 포기하
# > 게 됩니다.
# >   - 아직 전처리는 하지 않습니다. 여기서는 무엇이 있는지 보기만 합니다.
# >   - 없다는 것도 확인 결과입니다. 찾아봤는데 없었다면 위 예시처럼 그렇게 적어 두세요.
# >
# > - 결측 많은 컬럼
# >   - 결측 30%가 넘는 컬럼은 채우는 것보다 버리는 쪽이 나을 때가 많습니다.
# >   - 다만 그 컬럼이 3절 X에 들어 있다면 계획부터 다시 봐야 합니다.
# >   - 비어 있는 게 정상인 칸도 있습니다. 위 예시의 해제사유발생일이 그렇습니다. 지우기 전에 그 컬럼이 무슨 뜻인지 설명
# > 문서에서 확인하세요.
# >
# > - 이상한 값
# >   - 무응답을 9, 99, 999로 코딩해둔 데이터가 흔합니다. 숫자로 읽히니 오류처럼 안 보이지만 그대로 두면 평균이 망가집
# > 니다. 나이 999, 소득 -1도 같은 종류입니다.
# >   - describe()의 최댓값이 유난히 크면 의심하세요. 다만 확인해 보고 실제 값이면 그대로 둡니다. 위 예시의 115억짜리
# > 거래가 그런 경우입니다.
# >   - 음수도 무조건 오류는 아닙니다. 위 예시의 층 -1은 지하층을 뜻하는 정상 값이었습니다.
# >
# > - Y 분포
# >   - 3절 목표변수 Y 칸과 같은 값을 적게 됩니다. 두 곳이 다르면 한쪽이 잘못된 것입니다.
# >
# > - 중복 행
# >   - df.duplicated().sum()으로 셉니다. 여러 파일을 합친 데이터에서 특히 자주 나오고 그대로 두면 같은 행이 여러 번
# > 학습됩니다.
# >   - 반대로 겉보기에 같아 보이는데 실제로는 다른 건도 있습니다. 위 예시의 같은 단지·같은 날짜 거래가 그렇습니다.
# >
# > - 자료형이 잘못 읽힌 컬럼
# >   - info()에서 숫자여야 할 컬럼이 object로 나오면 값 안에 쉼표나 단위 문자가 섞여 있을 가능성이 큽니다.
# >   - 82,500이나 35kg 같은 값 하나 때문에 열 전체가 문자로 읽힙니다.
# >
# > - 범주형 컬럼의 값 종류 수
# >   - 위 예시의 아파트 3,847종처럼 종류가 많으면 그대로 더미 인코딩했을 때 열이 그만큼 불어납니다.
# >   - 반대로 어떤 범주의 건수가 극단적으로 적으면, 학습·검증 분할에서 한쪽으로 몰려 그 범주의 결과가 무의미해집니다.
# >
# > - 발견한 내용
# >   - 표의 숫자만으로 설명이 안 되는 부분을 씁니다.
# >   - 이상해 보이는 값이 실제 오류인지, 1절의 데이터 단위나 자료의 성격 때문에 나올 수 있는 값인지 구분해 보세요.
# >   - 표본이 어느 쪽으로 기울었는지도 함께 봅니다. 위 예시의 “팔린 물건만 있다”가 그런 경우입니다. 바꿀 수 없는 편향이
# > 라면 결론의 범위를 좁혀서 적습니다.
# >   - 여기서 걸린 문제는 6절의 대응 계획으로 이어지게 씁니다.

# %% [markdown]
# ## 5. 수행 계획
#
#
# | 주차 | 할 일 | 그 주에 나오는 결과물 |
# | --- | --- | --- |
# | 1주차 | 파일 600개를 하나로 합치기, 해제된 거래 1,924건 제외, 거래금액 콤마 제거 후 숫자<br>변환, 건축년도·층 숫자 변환, 지역코드를 구 이름으로 매핑, 파생변수 3개 생성(건축연<br>차, 계약월차, ㎡당 가격 — ㎡당 가격은 확인용이며 X에 넣지 않음) | 전처리 노트북 1개 +<br>apt_clean.csv |
# | 2주차 | 변수별 분포 확인, 거래금액 로그 변환 여부 판단, 자치구별 가격 비교(박스플롯 + 분산<br>분석), 자치구를 고정한 뒤 건축연차와 가격 관계 확인, 계약월차에 따른 시장 흐름 확<br>인 | EDA 노트북 1개 + 그래프 8장,<br>가설 ①②③에 대한 1차 판정 |
# | 3주차 | 선형회귀 · 랜덤포레스트 · 그래디언트 부스팅 학습, RMSE·MAE·R²로 비교, 변수<br>중요도로 자치구와 건축연차의 기여도 확인 | 모델 3개 성능 비교표 + 변수 중<br>요도 그래프 |
# | 4주차 | 가설 ①②③ 최종 판정과 결과 해석 정리, 발표용 PPT 작성(주제·데이터 소개 → EDA<br>→ 모델 비교 → 결론과 한계), 2절·6절에서 적은 데이터 한계를 결론 장에 반영, 조원<br>리허설 1회 | 발표용 PPT 15장 내외 + 발표<br>대본 |
# | 5주차 | 발표에서 받은 피드백을 항목별로 정리, 분석을 다시 돌려야 하는 지적부터 반영(예:<br>로그 변환 여부 변경), 그래프 축·설명 문구 수정, 결론 문장 다듬기, 최종본 제출 | 피드백 반영 목록(고침/안 고침<br>+ 이유) + 최종 PPT + 최종 노트<br>북 |

# %% [markdown]
# > **📝 작성방법 설명**
# >
# >
# > - 할 일
# >   - 이 데이터에서 실제로 해야 하는 작업으로 씁니다. “전처리”(×) → “거래금액 콤마 제거 후 숫자 변환, 해제된 거래
# > 1,924건 제외”(○)
# >   - 4절에서 확인한 내용이 그대로 1주차 할 일이 됩니다. 4절과 5절이 이어지지 않으면 둘 중 하나가 부실한 것입니다.
# >
# > - 그 주에 나오는 결과물
# >   - 끝났다고 말할 수 있는 것을 하나씩 적습니다. “EDA 하기”, “전처리 하기”는 언제 끝난 건지 알 수 없어 계획 구실을 못
# > 합니다.
# >   - clean.csv 1개, 그래프 8장, 성능 비교표 1개처럼 파일이나 개수로 셀 수 있으면 그 주가 끝났는지 스스로 판단할 수
# > 있습니다.
# >
# > - 주차 배분
# >   - 전처리는 생각보다 오래 걸립니다. 1주차에 전처리와 모델링을 같이 넣은 계획은 거의 밀립니다. 처음 해 보는 작업이
# > 라면 예상 시간의 두 배로 잡으세요.
# >   - 밀릴 것을 미리 가정하고 우선순위를 정해 둡니다. “모델 3개 중 2개를 먼저 돌리고 나머지는 시간이 남으면”처럼 적어
# > 두면, 마지막 주에 무엇을 포기할지 고민하지 않아도 됩니다.
# >   - 5주로 부족하면 주차를 더 늘려 잡아도 됩니다. 무리한 계획을 적어 내는 것보다 낫습니다.
# >
# > - 발표 PPT 주차
# >   - 한 주를 따로 잡으세요. 분석이 끝나면 발표 자료는 금방 만들 수 있다고 생각하지만 그렇지 않습니다. 그래프를 발표용
# > 으로 다시 그리고 축 이름과 단위를 붙이고 순서를 짜고 말로 설명해 보는 데 시간이 걸립니다. 모델링 주차에 끼워 넣으
# > 면 결국 발표 전날 밤에 몰립니다.
# >   - 구성은 이 보고서의 순서를 그대로 따라가면 됩니다. 주제와 데이터 소개(1·2절) → 분석 설계와 가설(3절) → 데이터
# > 확인과 EDA(4절) → 모델 결과 → 결론.
# >   - 마지막에 한계를 밝히는 장을 반드시 넣으세요. 6절에 적어 둔 내용이 그 장의 재료가 됩니다. 한계를 감춘 발표보다 알
# > 고 있다고 말하는 발표가 좋은 평가를 받습니다.
# >
# > - 피드백 반영 주차
# >   - 마지막 주는 새 분석을 시작하는 주가 아니라 받은 지적을 반영하는 주입니다. 여기에 모델을 하나 더 넣으면 정작 고칠
# > 시간이 없어집니다.
# >   - 피드백을 받으면 먼저 항목별로 적어 놓고 각각을 “고침 / 안 고침 + 이유”로 나누세요. 전부 고칠 필요는 없지만 판단
# > 한 흔적은 남겨야 합니다.
# >   - 분석을 다시 돌려야 하는 지적(전처리 방식·변수 선택·모델 설정)과 자료만 고치면 되는 지적(그래프 축·설명 문구·
# > 발표 순서)을 나눠 두면 시간 배분이 됩니다. 다시 돌리는 쪽부터 시작하세요.
# >   - 고치다 보면 앞 절의 내용도 같이 바뀝니다. 전처리 방식을 바꿨다면 4절 수치와 6절 대응 계획도 함께 손봐야 앞뒤가
# > 맞습니다.

# %% [markdown]
# ## 6. 예상되는 어려움
#
#
# - 자치구가 다른 변수의 효과를 전부 흡수할 수 있다. 가격의 대부분을 입지가 설명해서 정작 알고 싶은 건축
# 연차나 층의 기여도가 안 보일 수 있다 → 자치구를 뺀 모델과 넣은 모델을 둘 다 만들어 계수 변화를 같이 싣
# 는다. 계수가 크게 흔들리면 그 자체를 “입지 효과와 건물 특성이 분리되지 않는다”는 결과로 보고한다.
#
# - 거래가 적은 구는 표본이 부족하다. 종로구는 24개월치를 모아도 612건이라 구별로 나눠 보면 결과가 들쭉
# 날쭉할 수 있다 → 구별 건수를 먼저 세고 500건에 못 미치는 구는 인접 구와 묶거나 분석에서 빼고 뺐다는
# 사실을 결론에 밝힌다.
#
# - 건축연차와 재건축 기대가 뒤섞인다. 오래된 단지가 재건축 기대로 오히려 비싸면 가설 ②는 뒤집힌다 →
# 뒤집히면 그것 자체를 결과로 보고한다. 연차를 구간으로 나눠 30년 넘은 단지를 따로 보고 결론에 “재건축
# 기대는 이 데이터로 구분할 수 없다”는 한계를 적는다.

# %% [markdown]
# > **📝 작성방법 설명**
# >
# >
# > - 걱정되는 것
# >   - 4절에서 확인한 사실에서 끌어옵니다. “시간이 부족할 것 같다”, “어려울 것 같다”는 이 데이터에 대해 아무것도 말하
# > 지 않습니다.
# >   - 위 예시는 셋 다 4절에서 실제로 본 것(구별 중앙값 차이, 종로구 612건, 건축연차의 두 방향)에서 나왔습니다. 4절을
# > 제대로 봤다면 걱정거리는 저절로 나옵니다.
# >
# > - 대응
# >   - 걱정과 화살표로 짝지어 적습니다. 플랜 B는 미리 정해둘 때만 플랜입니다. 닥쳐서 정하면 그냥 사고입니다.
# >   - 실행 가능한 조치여야 합니다. “열심히 한다”, “다른 방법을 찾아본다”(×) → “자치구를 뺀 모델과 넣은 모델의 계수
# > 변화를 같이 싣는다”(○). 조원이 그 문장만 읽고 바로 움직일 수 있으면 충분합니다.
# >   - 문제를 완전히 없애지 못하는 경우도 많습니다. 그럴 때는 한계를 결론에 밝히는 것도 대응입니다. 위 첫 번째 항목의
# > “분리되지 않는다는 것 자체를 결과로 보고”, 세 번째 항목의 “이 데이터로 구분할 수 없다고 적는다”가 그런 방식입니
# > 다.
# >
# > - 개수
# >   - 두세 개면 충분합니다. 걱정을 많이 적는 것보다 실제로 벌어질 법한 것을 골라 대응을 구체적으로 쓰는 편이 낫습니다.
